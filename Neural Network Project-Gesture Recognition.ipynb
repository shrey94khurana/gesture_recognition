# %% [markdown]
# ## **<span style="color:Black">Gesture Recognition</span>**
#
# <span style="color:Green">__Problem Statement :__</span>
#
# Imagine you are working as a data scientist at a home electronics company which manufactures state of the art smart televisions. You want to develop a cool feature in the smart-TV that can recognise five different gestures performed by the user which will help users control the TV without using a remote.
#
# The gestures are continuously monitored by the webcam mounted on the TV. Each gesture corresponds to a specific command:
#
# Gesture	Corresponding Action
# Thumbs Up	Increase the volume.
# Thumbs Down	Decrease the volume.
# Left Swipe	'Jump' backwards 10 seconds.
# Right Swipe	'Jump' forward 10 seconds.
# Stop	Pause the movie.
# Each video is a sequence of 30 frames (or images).
#
# #### <span style="color:Green">__Objectives:__</span>
#
# <span style="color:Orange">__Generators:__</span> The generator should be able to take a batch of videos as input without any error. Steps like cropping, resizing and normalization should be performed successfully.
#
# <span style="color:Orange">__Model:__</span>
# Develop a model that is able to train without any errors which will be judged on the total number of parameters (as the inference(prediction) time should be less) and the accuracy achieved. As suggested by Snehansu, start training on a small amount of data and then proceed further.
#
# <span style="color:Orange">__Write up:__</span>
# This should contain the detailed procedure followed in choosing the final model. The write up should start with the reason for choosing the base model, then highlight the reasons and metrics taken into consideration to modify and experiment to arrive at the final model.
#
# #### <span style="color:Green">__Team Details:__</span>
#
# 1. Shrey Khurana
# 2. Aparna Vittala
# 3. Yashodhara Gowda

# %%
import numpy as np
import os
from skimage.transform import resize
from imageio import imread
import datetime
import os
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# We set the random seed so that the results don't vary drastically.

# %%
np.random.seed(30)
import random as rn
rn.seed(30)
from keras import backend as K
import tensorflow as tf
tf.random.set_seed(30)
# Out:
# 2023-01-09 10:42:22.710758: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-01-09 10:42:22.845364: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-01-09 10:42:22.886648: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-01-09 10:42:23.790319: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:/usr/local/cuda/lib:/usr/local/lib/x86_64-linux-gnu:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2023-01-09 10:42:23.790538: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:/usr/local/cuda/lib:/usr/local/lib/x86_64-linux-gnu:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2023-01-09 10:42:23.790554: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %% [markdown]
# In this block, you read the folder names for training and validation. You also set the `batch_size` here. Note that you set the batch size in such a way that you are able to use the GPU in full capacity. You keep increasing the batch size until the machine throws an error.

# %%
train_doc = np.random.permutation(open('Project_data/train.csv').readlines())
val_doc = np.random.permutation(open('Project_data/val.csv').readlines())
batch_size = 30 #experiment with the batch size

# %% [markdown]
# ## Generator
# This is one of the most important part of the code. The overall structure of the generator has been given. In the generator, you are going to preprocess the images as you have images of 2 different dimensions as well as create a batch of video frames. You have to experiment with `img_idx`, `y`,`z` and normalization such that you get high accuracy.

# %%
def cropResize(image, y, z):
    h, w = image.shape
    
    # if smaller image crop at center for 120x120
    if w == 160:
        image = image[:120, 20:140]

    # resize every image
    return resize(image, (y,z))

# %%
def normalizeImage(image):
    # applying normalization
    return image/255.0

# %%
def preprocessImage(image, y, z):
    return normalizeImage(cropResize(image, y, z))

# %%
def make3dFilter(x):
    return tuple([x]*3)

def make2dFilter(x):
    return tuple([x]*2)

# %%
def getBatchData(source_path, t, batch, batch_size, img_tensor):
    [x,y,z] = [len(img_tensor[0]),img_tensor[1], img_tensor[2]]
    img_idx = img_tensor[0]
    batch_data = np.zeros((batch_size,x,y,z,3)) # x is the number of images you use for each video, (y,z) is the final size of the input images and 3 is the number of channels RGB
    batch_labels = np.zeros((batch_size,5)) # batch_labels is the one hot representation of the output
    for folder in range(batch_size): # iterate over the batch_size
        imgs = os.listdir(source_path+'/'+ t[folder + (batch*batch_size)].split(';')[0]) # read all the images in the folder
        for idx,item in enumerate(img_idx): #  Iterate iver the frames/images of a folder to read them in
            image = imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)

            #crop the images and resize them. Note that the images are of 2 different shape 
            #and the conv3D will throw error if the inputs in a batch have different shapes

            # separate preprocessImage function is defined for cropping, resizing and normalizing images
            batch_data[folder,idx,:,:,0] = preprocessImage(image[:, :, 0], y, z)
            batch_data[folder,idx,:,:,1] = preprocessImage(image[:, :, 1], y, z)
            batch_data[folder,idx,:,:,2] = preprocessImage(image[:, :, 2], y, z)

        batch_labels[folder, int(t[folder + (batch*batch_size)].strip().split(';')[2])] = 1
    return batch_data, batch_labels

# %%
def generator(source_path, folder_list, batch_size, img_tensor):
    print( 'Source path = ', source_path, '; batch size =', batch_size)
    while True:
        t = np.random.permutation(folder_list)
        num_batches = int(len(folder_list)/batch_size)
        for batch in range(num_batches): # we iterate over the number of batches
            yield getBatchData(source_path, t, batch, batch_size, img_tensor)
        
        # write the code for the remaining data points which are left after full batches
        # checking if any remaining batches are there or not
        if len(folder_list)%batch_size != 0:
            # updated the batch size and yield
            batch_size = len(folder_list)%batch_size
            yield getBatchData(source_path, t, batch, batch_size, img_tensor)

# %% [markdown]
# Note here that a video is represented above in the generator as (number of images, height, width, number of channels). Take this into consideration while creating the model architecture.

# %%
curr_dt_time = datetime.datetime.now()
train_path = 'Project_data/train'
val_path = 'Project_data/val'
num_train_sequences = len(train_doc)
print('# training sequences =', num_train_sequences)
num_val_sequences = len(val_doc)
print('# validation sequences =', num_val_sequences)
num_epochs = 10
print ('# epochs =', num_epochs)
# Out:
# # training sequences = 663
# # validation sequences = 100
# # epochs = 10

# %%
def getImgTensor(n_frames):
    img_idx = np.round(np.linspace(0, 29, n_frames)).astype(int)
    return [img_idx, 100, 100, 3]

# define image tensor size
img_tensor = getImgTensor(20)
print ('# img_tensor =', img_tensor)
# Out:
# # img_tensor = [array([ 0,  2,  3,  5,  6,  8,  9, 11, 12, 14, 15, 17, 18, 20, 21, 23, 24,
#        26, 27, 29]), 100, 100, 3]

# %% [markdown]
# ### Generator Validation

# %%
# check complete batch shape
sample_generator = generator(train_path, train_doc, batch_size, img_tensor)
sample_batch_data, sample_batch_labels = next(sample_generator)
print(sample_batch_data.shape)

# validation batch sample
sample_val_generator = generator(val_path, val_doc, batch_size, img_tensor)
sample_val_batch_data, sample_val_batch_labels = next(sample_val_generator)
print(sample_val_batch_data.shape)
# Out:
# Source path =  Project_data/train ; batch size = 30
# (30, 20, 100, 100, 3)
# Source path =  Project_data/val ; batch size = 30
# (30, 20, 100, 100, 3)

# %%
# plot generated sample images
fig, ax = plt.subplots(1,2)
ax[0].imshow(sample_val_batch_data[16,10,:,:,:])   
ax[1].imshow(sample_val_batch_data[17,10,:,:,:])
plt.show()

# %%
def plotModelHistory(h):
    fig, ax = plt.subplots(1, 2, figsize=(15,4))
    ax[0].plot(h.history['loss'])   
    ax[0].plot(h.history['val_loss'])
    ax[0].legend(['loss','val_loss'])
    ax[0].title.set_text("Train loss vs Validation loss")

    ax[1].plot(h.history['categorical_accuracy'])   
    ax[1].plot(h.history['val_categorical_accuracy'])
    ax[1].legend(['categorical_accuracy','val_categorical_accuracy'])
    ax[1].title.set_text("Train accuracy vs Validation accuracy")
    plt.show()

    print("Max. Training Accuracy", max(h.history['categorical_accuracy']))
    print("Max. Validaiton Accuracy", max(h.history['val_categorical_accuracy']))

# %% [markdown]
# ## Model
# Here you make the model using different functionalities that Keras provides. Remember to use `Conv3D` and `MaxPooling3D` and not `Conv2D` and `Maxpooling2D` for a 3D convolution model. You would want to use `TimeDistributed` while building a Conv2D + RNN model. Also remember that the last layer is the softmax. Design the network in such a way that the model is able to give good accuracy on the least number of parameters so that it can fit in the memory of the webcam.

# %%
from keras.models import Sequential, Model
from keras.layers import Dense, GRU, Flatten, TimeDistributed, Flatten, BatchNormalization, Activation, Dropout, LSTM
from keras.layers.convolutional import Conv3D, MaxPooling3D, Conv2D, MaxPooling2D
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras import optimizers

# %% [markdown]
# ### Base Model

# %%
#write your model here
def defineModel(img_tensor):
    inputShape = (len(img_tensor[0]), img_tensor[1], img_tensor[2], img_tensor[3])

    model = Sequential([
        Conv3D(16, make3dFilter(5), activation='relu', input_shape=inputShape),
        MaxPooling3D(make3dFilter(2), padding='same'),
        BatchNormalization(),

        Conv3D(32, make3dFilter(3), activation='relu'),
        MaxPooling3D(pool_size=(1,2,2), padding='same'),
        BatchNormalization(),

        Conv3D(64, make3dFilter(3), activation='relu'),
        MaxPooling3D(pool_size=(1,2,2), padding='same'),
        BatchNormalization(),

        Flatten(),
        Dense(128, activation='relu'),
        BatchNormalization(),
        Dropout(0.25),

        Dense(64, activation='relu'),
        BatchNormalization(),
        Dropout(0.25),

        Dense(5, activation='softmax')
    ])
    model.compile(optimizer=optimizers.Adam(), loss='categorical_crossentropy', metrics=['categorical_accuracy'])
    return model

model = defineModel(img_tensor)
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d (Conv3D)             (None, 16, 96, 96, 16)    6016
#
#  max_pooling3d (MaxPooling3D  (None, 8, 48, 48, 16)    0
#  )
#
#  batch_normalization (BatchN  (None, 8, 48, 48, 16)    64
#  ormalization)
#
#  conv3d_1 (Conv3D)           (None, 6, 46, 46, 32)     13856
#
#  max_pooling3d_1 (MaxPooling  (None, 6, 23, 23, 32)    0
#  3D)
#
#  batch_normalization_1 (Batc  (None, 6, 23, 23, 32)    128
#  hNormalization)
#
#  conv3d_2 (Conv3D)           (None, 4, 21, 21, 64)     55360
#
#  max_pooling3d_2 (MaxPooling  (None, 4, 11, 11, 64)    0
#  3D)
#
#  batch_normalization_2 (Batc  (None, 4, 11, 11, 64)    256
#  hNormalization)
#
#  flatten (Flatten)           (None, 30976)             0
# 2023-01-09 10:42:45.937848: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-01-09 10:42:47.217103: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 38224 MB memory:  -> device: 0, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:00:04.0, compute capability: 8.0
# 2023-01-09 10:42:47.219059: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 38224 MB memory:  -> device: 1, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:00:05.0, compute capability: 8.0
#
#  dense (Dense)               (None, 128)               3965056
#
#  batch_normalization_3 (Batc  (None, 128)              512
#  hNormalization)
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  batch_normalization_4 (Batc  (None, 64)               256
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 5)                 325
#
# =================================================================
# Total params: 4,050,085
# Trainable params: 4,049,477
# Non-trainable params: 608
# _________________________________________________________________

# %%
train_generator = generator(train_path, train_doc, batch_size, img_tensor)
val_generator = generator(val_path, val_doc, batch_size, img_tensor)

# %% [markdown]
# The `steps_per_epoch` and `validation_steps` are used by `fit_generator` to decide the number of next() calls it need to make.

# %%
if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1

# %% [markdown]
# ### Model Callbacks Setup

# %%
model_name = 'model_init' + '_' + str(curr_dt_time).replace(' ','').replace(':','_') + '/'
    
if not os.path.exists(model_name):
    os.mkdir(model_name)

filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'

checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=False, save_weights_only=False, mode='auto', save_freq='epoch')

LR = ReduceLROnPlateau(monitor='val_loss', factor=0.2, verbose=1, patience=4)

callbacks_list = [checkpoint, LR]
#callbacks_list = [LR]

# %%
model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                    callbacks=callbacks_list, validation_data=val_generator, 
                    validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Epoch 1/10
# 23/23 [==============================] - ETA: 0s - loss: 1.5839 - categorical_accuracy: 0.4204Source path =  Project_data/val ; batch size = 30
#
# Epoch 1: saving model to model_init_2023-01-0910_42_32.286970/model-00001-1.58393-0.42036-12.38010-0.23000.h5
# 23/23 [==============================] - 95s 4s/step - loss: 1.5839 - categorical_accuracy: 0.4204 - val_loss: 12.3801 - val_categorical_accuracy: 0.2300 - lr: 0.0010
# Epoch 2/10
# 23/23 [==============================] - ETA: 0s - loss: 1.9329 - categorical_accuracy: 0.3043
# Epoch 2: saving model to model_init_2023-01-0910_42_32.286970/model-00002-1.93294-0.30435-14.40339-0.20000.h5
# 23/23 [==============================] - 16s 716ms/step - loss: 1.9329 - categorical_accuracy: 0.3043 - val_loss: 14.4034 - val_categorical_accuracy: 0.2000 - lr: 0.0010
# Epoch 3/10
# 23/23 [==============================] - ETA: 0s - loss: 1.9704 - categorical_accuracy: 0.2464
# Epoch 3: saving model to model_init_2023-01-0910_42_32.286970/model-00003-1.97039-0.24638-13.55228-0.25000.h5
# 23/23 [==============================] - 15s 676ms/step - loss: 1.9704 - categorical_accuracy: 0.2464 - val_loss: 13.5523 - val_categorical_accuracy: 0.2500 - lr: 0.0010
# Epoch 4/10
# 23/23 [==============================] - ETA: 0s - loss: 1.7795 - categorical_accuracy: 0.2319
# Epoch 4: saving model to model_init_2023-01-0910_42_32.286970/model-00004-1.77949-0.23188-6.16613-0.27500.h5
# 23/23 [==============================] - 17s 769ms/step - loss: 1.7795 - categorical_accuracy: 0.2319 - val_loss: 6.1661 - val_categorical_accuracy: 0.2750 - lr: 0.0010
# Epoch 5/10
# 23/23 [==============================] - ETA: 0s - loss: 1.8789 - categorical_accuracy: 0.2609
# Epoch 5: saving model to model_init_2023-01-0910_42_32.286970/model-00005-1.87889-0.26087-4.77839-0.32500.h5
# 23/23 [==============================] - 17s 752ms/step - loss: 1.8789 - categorical_accuracy: 0.2609 - val_loss: 4.7784 - val_categorical_accuracy: 0.3250 - lr: 0.0010
# Epoch 6/10
# 23/23 [==============================] - ETA: 0s - loss: 2.0681 - categorical_accuracy: 0.2899
# Epoch 6: saving model to model_init_2023-01-0910_42_32.286970/model-00006-2.06810-0.28986-2.10397-0.37500.h5
# 23/23 [==============================] - 17s 760ms/step - loss: 2.0681 - categorical_accuracy: 0.2899 - val_loss: 2.1040 - val_categorical_accuracy: 0.3750 - lr: 0.0010
# Epoch 7/10
# 23/23 [==============================] - ETA: 0s - loss: 1.7978 - categorical_accuracy: 0.3478
# Epoch 7: saving model to model_init_2023-01-0910_42_32.286970/model-00007-1.79780-0.34783-2.62019-0.32500.h5
# 23/23 [==============================] - 18s 813ms/step - loss: 1.7978 - categorical_accuracy: 0.3478 - val_loss: 2.6202 - val_categorical_accuracy: 0.3250 - lr: 0.0010
# Epoch 8/10
# 23/23 [==============================] - ETA: 0s - loss: 1.9250 - categorical_accuracy: 0.2174
# Epoch 8: saving model to model_init_2023-01-0910_42_32.286970/model-00008-1.92501-0.21739-5.25883-0.17500.h5
# 23/23 [==============================] - 16s 716ms/step - loss: 1.9250 - categorical_accuracy: 0.2174 - val_loss: 5.2588 - val_categorical_accuracy: 0.1750 - lr: 0.0010
# Epoch 9/10
# 23/23 [==============================] - ETA: 0s - loss: 1.6306 - categorical_accuracy: 0.3768
# Epoch 9: saving model to model_init_2023-01-0910_42_32.286970/model-00009-1.63056-0.37681-4.81738-0.17500.h5
# 23/23 [==============================] - 17s 752ms/step - loss: 1.6306 - categorical_accuracy: 0.3768 - val_loss: 4.8174 - val_categorical_accuracy: 0.1750 - lr: 0.0010
# Epoch 10/10
# 23/23 [==============================] - ETA: 0s - loss: 1.8818 - categorical_accuracy: 0.2464
# Epoch 10: saving model to model_init_2023-01-0910_42_32.286970/model-00010-1.88183-0.24638-2.87732-0.30000.h5
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 23/23 [==============================] - 17s 784ms/step - loss: 1.8818 - categorical_accuracy: 0.2464 - val_loss: 2.8773 - val_categorical_accuracy: 0.3000 - lr: 0.0010

# %% [markdown]
# ### Test Batch Size & Frames

# %%
def testBatchSize(batch_size, n_frames):
    img_tensor = getImgTensor(n_frames)
    print("Using frames as", img_tensor[0])
    global callbacks_list
    num_epochs = 3
    train_generator = generator(train_path, train_doc, batch_size, img_tensor)
    val_generator = generator(val_path, val_doc, batch_size, img_tensor)
    if (num_train_sequences%batch_size) == 0:
        steps_per_epoch = int(num_train_sequences/batch_size)
    else:
        steps_per_epoch = (num_train_sequences//batch_size) + 1

    if (num_val_sequences%batch_size) == 0:
        validation_steps = int(num_val_sequences/batch_size)
    else:
        validation_steps = (num_val_sequences//batch_size) + 1

    model = defineModel(img_tensor)
    model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                callbacks=callbacks_list, validation_data=val_generator, 
                validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)

# %% [markdown]
# With above observations, we can see that batch size is not impacting training time but number of frames. We will use batch size of 64 as it seems optimal. It is commented as it takes a lot of time to run that is restricting for the notebook to completely run.

# %% [markdown]
# ### Model 1 - Frames-16, Epoc-20

# %%
n_frames = 16
num_epochs = 20
batch_size = 64

img_tensor = getImgTensor(n_frames)
train_generator = generator(train_path, train_doc, batch_size, img_tensor)
val_generator = generator(val_path, val_doc, batch_size, img_tensor)

if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1
    
inputShape = (len(img_tensor[0]), img_tensor[1], img_tensor[2], img_tensor[3])

model1 = Sequential([
    Conv3D(16, make3dFilter(5), activation='relu', input_shape=inputShape),
    MaxPooling3D(make3dFilter(2), padding='same'),
    BatchNormalization(),

    Conv3D(32, make3dFilter(3), activation='relu'),
    MaxPooling3D(pool_size=(1,2,2), padding='same'),
    BatchNormalization(),

    Conv3D(64, make3dFilter(3), activation='relu'),
    MaxPooling3D(pool_size=(1,2,2), padding='same'),
    BatchNormalization(),

    Flatten(),
    Dense(128, activation='relu'),
    BatchNormalization(),
    Dropout(0.25),

    Dense(64, activation='relu'),
    BatchNormalization(),
    Dropout(0.25),

    Dense(5, activation='softmax')
], name="conv_3d1")
model1.compile(optimizer=optimizers.Adam(), loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print(model1.summary())

model1_history = model1.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
            callbacks=callbacks_list, validation_data=val_generator, 
            validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Model: "conv_3d1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_3 (Conv3D)           (None, 12, 96, 96, 16)    6016
#
#  max_pooling3d_3 (MaxPooling  (None, 6, 48, 48, 16)    0
#  3D)
#
#  batch_normalization_5 (Batc  (None, 6, 48, 48, 16)    64
#  hNormalization)
#
#  conv3d_4 (Conv3D)           (None, 4, 46, 46, 32)     13856
#
#  max_pooling3d_4 (MaxPooling  (None, 4, 23, 23, 32)    0
#  3D)
#
#  batch_normalization_6 (Batc  (None, 4, 23, 23, 32)    128
#  hNormalization)
#
#  conv3d_5 (Conv3D)           (None, 2, 21, 21, 64)     55360
#
#  max_pooling3d_5 (MaxPooling  (None, 2, 11, 11, 64)    0
#  3D)
#
#  batch_normalization_7 (Batc  (None, 2, 11, 11, 64)    256
#  hNormalization)
#
#  flatten_1 (Flatten)         (None, 15488)             0
#
#  dense_3 (Dense)             (None, 128)               1982592
#
#  batch_normalization_8 (Batc  (None, 128)              512
#  hNormalization)
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_4 (Dense)             (None, 64)                8256
#
#  batch_normalization_9 (Batc  (None, 64)               256
#  hNormalization)
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense_5 (Dense)             (None, 5)                 325
#
# =================================================================
# Total params: 2,067,621
# Trainable params: 2,067,013
# Non-trainable params: 608
# _________________________________________________________________
# None
# Source path =  Project_data/train ; batch size = 64
# Epoch 1/20
# 11/11 [==============================] - ETA: 0s - loss: 1.4193 - categorical_accuracy: 0.4977Source path =  Project_data/val ; batch size = 64
#
# Epoch 1: saving model to model_init_2023-01-0910_42_32.286970/model-00001-1.41928-0.49774-3.93272-0.23000.h5
# 11/11 [==============================] - 81s 8s/step - loss: 1.4193 - categorical_accuracy: 0.4977 - val_loss: 3.9327 - val_categorical_accuracy: 0.2300 - lr: 0.0010
# Epoch 2/20
# 11/11 [==============================] - ETA: 0s - loss: 1.0234 - categorical_accuracy: 0.6403
# Epoch 2: saving model to model_init_2023-01-0910_42_32.286970/model-00002-1.02344-0.64032-2.83869-0.28125.h5
# 11/11 [==============================] - 36s 4s/step - loss: 1.0234 - categorical_accuracy: 0.6403 - val_loss: 2.8387 - val_categorical_accuracy: 0.2812 - lr: 0.0010
# Epoch 3/20
# 11/11 [==============================] - ETA: 0s - loss: 1.0590 - categorical_accuracy: 0.5692
# Epoch 3: saving model to model_init_2023-01-0910_42_32.286970/model-00003-1.05900-0.56917-4.31585-0.21429.h5
# 11/11 [==============================] - 35s 3s/step - loss: 1.0590 - categorical_accuracy: 0.5692 - val_loss: 4.3159 - val_categorical_accuracy: 0.2143 - lr: 0.0010
# Epoch 4/20
# 11/11 [==============================] - ETA: 0s - loss: 0.7834 - categorical_accuracy: 0.6910
# Epoch 4: saving model to model_init_2023-01-0910_42_32.286970/model-00004-0.78340-0.69099-3.43925-0.37500.h5
# 11/11 [==============================] - 29s 3s/step - loss: 0.7834 - categorical_accuracy: 0.6910 - val_loss: 3.4392 - val_categorical_accuracy: 0.3750 - lr: 0.0010
# Epoch 5/20
# 11/11 [==============================] - ETA: 0s - loss: 0.8430 - categorical_accuracy: 0.6555
# Epoch 5: saving model to model_init_2023-01-0910_42_32.286970/model-00005-0.84297-0.65550-5.70757-0.12500.h5
# 11/11 [==============================] - 26s 3s/step - loss: 0.8430 - categorical_accuracy: 0.6555 - val_loss: 5.7076 - val_categorical_accuracy: 0.1250 - lr: 0.0010
# Epoch 6/20
# 11/11 [==============================] - ETA: 0s - loss: 0.8186 - categorical_accuracy: 0.6651
# Epoch 6: saving model to model_init_2023-01-0910_42_32.286970/model-00006-0.81863-0.66507-7.34084-0.12500.h5
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 11/11 [==============================] - 22s 2s/step - loss: 0.8186 - categorical_accuracy: 0.6651 - val_loss: 7.3408 - val_categorical_accuracy: 0.1250 - lr: 0.0010
# Epoch 7/20
# 11/11 [==============================] - ETA: 0s - loss: 0.8347 - categorical_accuracy: 0.6502
# Epoch 7: saving model to model_init_2023-01-0910_42_32.286970/model-00007-0.83469-0.65025-4.55023-0.12500.h5
# 11/11 [==============================] - 22s 2s/step - loss: 0.8347 - categorical_accuracy: 0.6502 - val_loss: 4.5502 - val_categorical_accuracy: 0.1250 - lr: 2.0000e-04
# Epoch 8/20
# 11/11 [==============================] - ETA: 0s - loss: 0.6745 - categorical_accuracy: 0.7326
# Epoch 8: saving model to model_init_2023-01-0910_42_32.286970/model-00008-0.67451-0.73262-4.92628-0.00000.h5
# 11/11 [==============================] - 20s 2s/step - loss: 0.6745 - categorical_accuracy: 0.7326 - val_loss: 4.9263 - val_categorical_accuracy: 0.0000e+00 - lr: 2.0000e-04
# Epoch 9/20
# 11/11 [==============================] - ETA: 0s - loss: 0.5795 - categorical_accuracy: 0.7754
# Epoch 9: saving model to model_init_2023-01-0910_42_32.286970/model-00009-0.57947-0.77540-1.61571-0.37500.h5
# 11/11 [==============================] - 21s 2s/step - loss: 0.5795 - categorical_accuracy: 0.7754 - val_loss: 1.6157 - val_categorical_accuracy: 0.3750 - lr: 2.0000e-04
# Epoch 10/20
# 11/11 [==============================] - ETA: 0s - loss: 0.6269 - categorical_accuracy: 0.7487
# Epoch 10: saving model to model_init_2023-01-0910_42_32.286970/model-00010-0.62694-0.74866-1.38757-0.25000.h5
# 11/11 [==============================] - 20s 2s/step - loss: 0.6269 - categorical_accuracy: 0.7487 - val_loss: 1.3876 - val_categorical_accuracy: 0.2500 - lr: 2.0000e-04
# Epoch 11/20
# 11/11 [==============================] - ETA: 0s - loss: 0.5817 - categorical_accuracy: 0.7861
# Epoch 11: saving model to model_init_2023-01-0910_42_32.286970/model-00011-0.58169-0.78610-2.65959-0.12500.h5
# 11/11 [==============================] - 20s 2s/step - loss: 0.5817 - categorical_accuracy: 0.7861 - val_loss: 2.6596 - val_categorical_accuracy: 0.1250 - lr: 2.0000e-04
# Epoch 12/20
# 11/11 [==============================] - ETA: 0s - loss: 0.4764 - categorical_accuracy: 0.8182
# Epoch 12: saving model to model_init_2023-01-0910_42_32.286970/model-00012-0.47642-0.81818-2.28122-0.00000.h5
# 11/11 [==============================] - 19s 2s/step - loss: 0.4764 - categorical_accuracy: 0.8182 - val_loss: 2.2812 - val_categorical_accuracy: 0.0000e+00 - lr: 2.0000e-04
# Epoch 13/20
# 11/11 [==============================] - ETA: 0s - loss: 0.5629 - categorical_accuracy: 0.7754
# Epoch 13: saving model to model_init_2023-01-0910_42_32.286970/model-00013-0.56291-0.77540-2.24203-0.12500.h5
# 11/11 [==============================] - 22s 2s/step - loss: 0.5629 - categorical_accuracy: 0.7754 - val_loss: 2.2420 - val_categorical_accuracy: 0.1250 - lr: 2.0000e-04
# Epoch 14/20
# 11/11 [==============================] - ETA: 0s - loss: 0.6032 - categorical_accuracy: 0.7754
# Epoch 14: saving model to model_init_2023-01-0910_42_32.286970/model-00014-0.60319-0.77540-1.86733-0.25000.h5
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 11/11 [==============================] - 20s 2s/step - loss: 0.6032 - categorical_accuracy: 0.7754 - val_loss: 1.8673 - val_categorical_accuracy: 0.2500 - lr: 2.0000e-04
# Epoch 15/20
# 11/11 [==============================] - ETA: 0s - loss: 0.4899 - categorical_accuracy: 0.8289
# Epoch 15: saving model to model_init_2023-01-0910_42_32.286970/model-00015-0.48991-0.82888-1.55313-0.37500.h5
# 11/11 [==============================] - 21s 2s/step - loss: 0.4899 - categorical_accuracy: 0.8289 - val_loss: 1.5531 - val_categorical_accuracy: 0.3750 - lr: 4.0000e-05
# Epoch 16/20
# 11/11 [==============================] - ETA: 0s - loss: 0.4153 - categorical_accuracy: 0.8663
# Epoch 16: saving model to model_init_2023-01-0910_42_32.286970/model-00016-0.41528-0.86631-1.52043-0.25000.h5
# 11/11 [==============================] - 19s 2s/step - loss: 0.4153 - categorical_accuracy: 0.8663 - val_loss: 1.5204 - val_categorical_accuracy: 0.2500 - lr: 4.0000e-05
# Epoch 17/20
# 11/11 [==============================] - ETA: 0s - loss: 0.4395 - categorical_accuracy: 0.8556
# Epoch 17: saving model to model_init_2023-01-0910_42_32.286970/model-00017-0.43951-0.85561-1.60366-0.37500.h5
# 11/11 [==============================] - 21s 2s/step - loss: 0.4395 - categorical_accuracy: 0.8556 - val_loss: 1.6037 - val_categorical_accuracy: 0.3750 - lr: 4.0000e-05
# Epoch 18/20
# 11/11 [==============================] - ETA: 0s - loss: 0.3912 - categorical_accuracy: 0.8770
# Epoch 18: saving model to model_init_2023-01-0910_42_32.286970/model-00018-0.39124-0.87701-0.49787-0.87500.h5
# 11/11 [==============================] - 20s 2s/step - loss: 0.3912 - categorical_accuracy: 0.8770 - val_loss: 0.4979 - val_categorical_accuracy: 0.8750 - lr: 4.0000e-05
# Epoch 19/20
# 11/11 [==============================] - ETA: 0s - loss: 0.4387 - categorical_accuracy: 0.8824
# Epoch 19: saving model to model_init_2023-01-0910_42_32.286970/model-00019-0.43873-0.88235-1.44911-0.37500.h5
# 11/11 [==============================] - 22s 2s/step - loss: 0.4387 - categorical_accuracy: 0.8824 - val_loss: 1.4491 - val_categorical_accuracy: 0.3750 - lr: 4.0000e-05
# Epoch 20/20
# 11/11 [==============================] - ETA: 0s - loss: 0.4764 - categorical_accuracy: 0.7914
# Epoch 20: saving model to model_init_2023-01-0910_42_32.286970/model-00020-0.47639-0.79144-1.53026-0.50000.h5
# 11/11 [==============================] - 19s 2s/step - loss: 0.4764 - categorical_accuracy: 0.7914 - val_loss: 1.5303 - val_categorical_accuracy: 0.5000 - lr: 4.0000e-05

# %%
plotModelHistory(model1_history)
# Out:
# Max. Training Accuracy 0.8823529481887817
# Max. Validaiton Accuracy 0.875

# %% [markdown]
# ### Model 2: Frames-30, Epocs-30

# %%
n_frames = 30
num_epochs = 30
batch_size = 64

img_tensor = getImgTensor(n_frames)
train_generator = generator(train_path, train_doc, batch_size, img_tensor)
val_generator = generator(val_path, val_doc, batch_size, img_tensor)

if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1
    
inputShape = (len(img_tensor[0]), img_tensor[1], img_tensor[2], img_tensor[3])

model2 = Sequential([
    Conv3D(16, make3dFilter(5), activation='relu', input_shape=inputShape),
    MaxPooling3D(make3dFilter(2), padding='same'),
    BatchNormalization(),

    Conv3D(32, make3dFilter(3), activation='relu'),
    MaxPooling3D(pool_size=(1,2,2), padding='same'),
    BatchNormalization(),

    Conv3D(64, make3dFilter(3), activation='relu'),
    MaxPooling3D(pool_size=(1,2,2), padding='same'),
    BatchNormalization(),

    Flatten(),
    Dense(128, activation='relu'),
    BatchNormalization(),
    Dropout(0.25),

    Dense(64, activation='relu'),
    BatchNormalization(),
    Dropout(0.25),

    Dense(5, activation='softmax')
], name="conv_3d2")
model2.compile(optimizer=optimizers.Adam(), loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print(model2.summary())

model2_history = model2.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
            callbacks=callbacks_list, validation_data=val_generator, 
            validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Model: "conv_3d2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_6 (Conv3D)           (None, 26, 96, 96, 16)    6016
#
#  max_pooling3d_6 (MaxPooling  (None, 13, 48, 48, 16)   0
#  3D)
#
#  batch_normalization_10 (Bat  (None, 13, 48, 48, 16)   64
#  chNormalization)
#
#  conv3d_7 (Conv3D)           (None, 11, 46, 46, 32)    13856
#
#  max_pooling3d_7 (MaxPooling  (None, 11, 23, 23, 32)   0
#  3D)
#
#  batch_normalization_11 (Bat  (None, 11, 23, 23, 32)   128
#  chNormalization)
#
#  conv3d_8 (Conv3D)           (None, 9, 21, 21, 64)     55360
#
#  max_pooling3d_8 (MaxPooling  (None, 9, 11, 11, 64)    0
#  3D)
#
#  batch_normalization_12 (Bat  (None, 9, 11, 11, 64)    256
#  chNormalization)
#
#  flatten_2 (Flatten)         (None, 69696)             0
#
#  dense_6 (Dense)             (None, 128)               8921216
#
#  batch_normalization_13 (Bat  (None, 128)              512
#  chNormalization)
#
#  dropout_4 (Dropout)         (None, 128)               0
#
#  dense_7 (Dense)             (None, 64)                8256
#
#  batch_normalization_14 (Bat  (None, 64)               256
#  chNormalization)
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  dense_8 (Dense)             (None, 5)                 325
#
# =================================================================
# Total params: 9,006,245
# Trainable params: 9,005,637
# Non-trainable params: 608
# _________________________________________________________________
# None
# Source path =  Project_data/train ; batch size = 64
# Epoch 1/30
# 11/11 [==============================] - ETA: 0s - loss: 1.5065 - categorical_accuracy: 0.4374 Source path =  Project_data/val ; batch size = 64
#
# Epoch 1: saving model to model_init_2023-01-0910_42_32.286970/model-00001-1.50646-0.43741-6.37920-0.23000.h5
# 11/11 [==============================] - 150s 15s/step - loss: 1.5065 - categorical_accuracy: 0.4374 - val_loss: 6.3792 - val_categorical_accuracy: 0.2300 - lr: 0.0010
# Epoch 2/30
# 11/11 [==============================] - ETA: 0s - loss: 1.0307 - categorical_accuracy: 0.6166
# Epoch 2: saving model to model_init_2023-01-0910_42_32.286970/model-00002-1.03070-0.61660-8.04876-0.18750.h5
# 11/11 [==============================] - 69s 7s/step - loss: 1.0307 - categorical_accuracy: 0.6166 - val_loss: 8.0488 - val_categorical_accuracy: 0.1875 - lr: 0.0010
# Epoch 3/30
# 11/11 [==============================] - ETA: 0s - loss: 0.9492 - categorical_accuracy: 0.5692
# Epoch 3: saving model to model_init_2023-01-0910_42_32.286970/model-00003-0.94922-0.56917-6.87371-0.23214.h5
# 11/11 [==============================] - 66s 7s/step - loss: 0.9492 - categorical_accuracy: 0.5692 - val_loss: 6.8737 - val_categorical_accuracy: 0.2321 - lr: 0.0010
# Epoch 4/30
# 11/11 [==============================] - ETA: 0s - loss: 0.8572 - categorical_accuracy: 0.6781
# Epoch 4: saving model to model_init_2023-01-0910_42_32.286970/model-00004-0.85719-0.67811-2.79405-0.28125.h5
# 11/11 [==============================] - 52s 5s/step - loss: 0.8572 - categorical_accuracy: 0.6781 - val_loss: 2.7941 - val_categorical_accuracy: 0.2812 - lr: 0.0010
# Epoch 5/30
# 11/11 [==============================] - ETA: 0s - loss: 0.7699 - categorical_accuracy: 0.7081
# Epoch 5: saving model to model_init_2023-01-0910_42_32.286970/model-00005-0.76988-0.70813-2.26655-0.28125.h5
# 11/11 [==============================] - 49s 5s/step - loss: 0.7699 - categorical_accuracy: 0.7081 - val_loss: 2.2665 - val_categorical_accuracy: 0.2812 - lr: 0.0010
# Epoch 6/30
# 11/11 [==============================] - ETA: 0s - loss: 0.7926 - categorical_accuracy: 0.7177
# Epoch 6: saving model to model_init_2023-01-0910_42_32.286970/model-00006-0.79258-0.71770-3.74617-0.37500.h5
# 11/11 [==============================] - 41s 4s/step - loss: 0.7926 - categorical_accuracy: 0.7177 - val_loss: 3.7462 - val_categorical_accuracy: 0.3750 - lr: 0.0010
# Epoch 7/30
# 11/11 [==============================] - ETA: 0s - loss: 0.9013 - categorical_accuracy: 0.6108
# Epoch 7: saving model to model_init_2023-01-0910_42_32.286970/model-00007-0.90127-0.61084-2.95355-0.37500.h5
# 11/11 [==============================] - 41s 4s/step - loss: 0.9013 - categorical_accuracy: 0.6108 - val_loss: 2.9536 - val_categorical_accuracy: 0.3750 - lr: 0.0010
# Epoch 8/30
# 11/11 [==============================] - ETA: 0s - loss: 0.9642 - categorical_accuracy: 0.6631
# Epoch 8: saving model to model_init_2023-01-0910_42_32.286970/model-00008-0.96423-0.66310-3.88955-0.00000.h5
# 11/11 [==============================] - 37s 4s/step - loss: 0.9642 - categorical_accuracy: 0.6631 - val_loss: 3.8896 - val_categorical_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 9/30
# 11/11 [==============================] - ETA: 0s - loss: 0.9197 - categorical_accuracy: 0.6417
# Epoch 9: saving model to model_init_2023-01-0910_42_32.286970/model-00009-0.91975-0.64171-21.21167-0.25000.h5
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 11/11 [==============================] - 38s 4s/step - loss: 0.9197 - categorical_accuracy: 0.6417 - val_loss: 21.2117 - val_categorical_accuracy: 0.2500 - lr: 0.0010
# Epoch 10/30
# 11/11 [==============================] - ETA: 0s - loss: 1.0835 - categorical_accuracy: 0.5936
# Epoch 10: saving model to model_init_2023-01-0910_42_32.286970/model-00010-1.08349-0.59358-13.48259-0.25000.h5
# 11/11 [==============================] - 39s 4s/step - loss: 1.0835 - categorical_accuracy: 0.5936 - val_loss: 13.4826 - val_categorical_accuracy: 0.2500 - lr: 2.0000e-04
# Epoch 11/30
# 11/11 [==============================] - ETA: 0s - loss: 0.8540 - categorical_accuracy: 0.6845
# Epoch 11: saving model to model_init_2023-01-0910_42_32.286970/model-00011-0.85405-0.68449-8.31383-0.25000.h5
# 11/11 [==============================] - 37s 4s/step - loss: 0.8540 - categorical_accuracy: 0.6845 - val_loss: 8.3138 - val_categorical_accuracy: 0.2500 - lr: 2.0000e-04
# Epoch 12/30
# 11/11 [==============================] - ETA: 0s - loss: 0.8226 - categorical_accuracy: 0.6898
# Epoch 12: saving model to model_init_2023-01-0910_42_32.286970/model-00012-0.82257-0.68984-6.95307-0.12500.h5
# 11/11 [==============================] - 39s 4s/step - loss: 0.8226 - categorical_accuracy: 0.6898 - val_loss: 6.9531 - val_categorical_accuracy: 0.1250 - lr: 2.0000e-04
# Epoch 13/30
# 11/11 [==============================] - ETA: 0s - loss: 0.7676 - categorical_accuracy: 0.6952
# Epoch 13: saving model to model_init_2023-01-0910_42_32.286970/model-00013-0.76764-0.69519-6.17127-0.12500.h5
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 11/11 [==============================] - 40s 4s/step - loss: 0.7676 - categorical_accuracy: 0.6952 - val_loss: 6.1713 - val_categorical_accuracy: 0.1250 - lr: 2.0000e-04
# Epoch 14/30
# 11/11 [==============================] - ETA: 0s - loss: 0.7154 - categorical_accuracy: 0.7166
# Epoch 14: saving model to model_init_2023-01-0910_42_32.286970/model-00014-0.71543-0.71658-1.78533-0.62500.h5
# 11/11 [==============================] - 36s 4s/step - loss: 0.7154 - categorical_accuracy: 0.7166 - val_loss: 1.7853 - val_categorical_accuracy: 0.6250 - lr: 4.0000e-05
# Epoch 15/30
# 11/11 [==============================] - ETA: 0s - loss: 0.6961 - categorical_accuracy: 0.7754
# Epoch 15: saving model to model_init_2023-01-0910_42_32.286970/model-00015-0.69609-0.77540-2.80113-0.25000.h5
# 11/11 [==============================] - 39s 4s/step - loss: 0.6961 - categorical_accuracy: 0.7754 - val_loss: 2.8011 - val_categorical_accuracy: 0.2500 - lr: 4.0000e-05
# Epoch 16/30
# 11/11 [==============================] - ETA: 0s - loss: 0.6412 - categorical_accuracy: 0.7487
# Epoch 16: saving model to model_init_2023-01-0910_42_32.286970/model-00016-0.64117-0.74866-2.11731-0.50000.h5
# 11/11 [==============================] - 38s 4s/step - loss: 0.6412 - categorical_accuracy: 0.7487 - val_loss: 2.1173 - val_categorical_accuracy: 0.5000 - lr: 4.0000e-05
# Epoch 17/30
# 11/11 [==============================] - ETA: 0s - loss: 0.7378 - categorical_accuracy: 0.6791
# Epoch 17: saving model to model_init_2023-01-0910_42_32.286970/model-00017-0.73777-0.67914-2.25953-0.25000.h5
# 11/11 [==============================] - 37s 4s/step - loss: 0.7378 - categorical_accuracy: 0.6791 - val_loss: 2.2595 - val_categorical_accuracy: 0.2500 - lr: 4.0000e-05
# Epoch 18/30
# 11/11 [==============================] - ETA: 0s - loss: 0.6407 - categorical_accuracy: 0.7647
# Epoch 18: saving model to model_init_2023-01-0910_42_32.286970/model-00018-0.64075-0.76471-2.16731-0.25000.h5
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 11/11 [==============================] - 36s 4s/step - loss: 0.6407 - categorical_accuracy: 0.7647 - val_loss: 2.1673 - val_categorical_accuracy: 0.2500 - lr: 4.0000e-05
# Epoch 19/30
# 11/11 [==============================] - ETA: 0s - loss: 0.7146 - categorical_accuracy: 0.7112
# Epoch 19: saving model to model_init_2023-01-0910_42_32.286970/model-00019-0.71457-0.71123-1.68872-0.12500.h5
# 11/11 [==============================] - 37s 4s/step - loss: 0.7146 - categorical_accuracy: 0.7112 - val_loss: 1.6887 - val_categorical_accuracy: 0.1250 - lr: 8.0000e-06
# Epoch 20/30
# 11/11 [==============================] - ETA: 0s - loss: 0.7050 - categorical_accuracy: 0.7433
# Epoch 20: saving model to model_init_2023-01-0910_42_32.286970/model-00020-0.70501-0.74332-2.10139-0.12500.h5
# 11/11 [==============================] - 39s 4s/step - loss: 0.7050 - categorical_accuracy: 0.7433 - val_loss: 2.1014 - val_categorical_accuracy: 0.1250 - lr: 8.0000e-06
# Epoch 21/30
# 11/11 [==============================] - ETA: 0s - loss: 0.6276 - categorical_accuracy: 0.7914
# Epoch 21: saving model to model_init_2023-01-0910_42_32.286970/model-00021-0.62755-0.79144-1.15406-0.25000.h5
# 11/11 [==============================] - 36s 4s/step - loss: 0.6276 - categorical_accuracy: 0.7914 - val_loss: 1.1541 - val_categorical_accuracy: 0.2500 - lr: 8.0000e-06
# Epoch 22/30
# 11/11 [==============================] - ETA: 0s - loss: 0.7458 - categorical_accuracy: 0.7005
# Epoch 22: saving model to model_init_2023-01-0910_42_32.286970/model-00022-0.74584-0.70053-1.73083-0.50000.h5
# 11/11 [==============================] - 36s 4s/step - loss: 0.7458 - categorical_accuracy: 0.7005 - val_loss: 1.7308 - val_categorical_accuracy: 0.5000 - lr: 8.0000e-06
# Epoch 23/30
# 11/11 [==============================] - ETA: 0s - loss: 0.5839 - categorical_accuracy: 0.7968
# Epoch 23: saving model to model_init_2023-01-0910_42_32.286970/model-00023-0.58389-0.79679-0.89354-0.75000.h5
# 11/11 [==============================] - 38s 4s/step - loss: 0.5839 - categorical_accuracy: 0.7968 - val_loss: 0.8935 - val_categorical_accuracy: 0.7500 - lr: 8.0000e-06
# Epoch 24/30
# 11/11 [==============================] - ETA: 0s - loss: 0.6816 - categorical_accuracy: 0.7540
# Epoch 24: saving model to model_init_2023-01-0910_42_32.286970/model-00024-0.68156-0.75401-1.31692-0.25000.h5
# 11/11 [==============================] - 38s 4s/step - loss: 0.6816 - categorical_accuracy: 0.7540 - val_loss: 1.3169 - val_categorical_accuracy: 0.2500 - lr: 8.0000e-06
# Epoch 25/30
# 11/11 [==============================] - ETA: 0s - loss: 0.5832 - categorical_accuracy: 0.8021
# Epoch 25: saving model to model_init_2023-01-0910_42_32.286970/model-00025-0.58320-0.80214-1.77009-0.25000.h5
# 11/11 [==============================] - 38s 4s/step - loss: 0.5832 - categorical_accuracy: 0.8021 - val_loss: 1.7701 - val_categorical_accuracy: 0.2500 - lr: 8.0000e-06
# Epoch 26/30
# 11/11 [==============================] - ETA: 0s - loss: 0.7547 - categorical_accuracy: 0.7273
# Epoch 26: saving model to model_init_2023-01-0910_42_32.286970/model-00026-0.75468-0.72727-1.71492-0.37500.h5
# 11/11 [==============================] - 39s 4s/step - loss: 0.7547 - categorical_accuracy: 0.7273 - val_loss: 1.7149 - val_categorical_accuracy: 0.3750 - lr: 8.0000e-06
# Epoch 27/30
# 11/11 [==============================] - ETA: 0s - loss: 0.5380 - categorical_accuracy: 0.7914
# Epoch 27: saving model to model_init_2023-01-0910_42_32.286970/model-00027-0.53799-0.79144-1.72895-0.62500.h5
#
# Epoch 27: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# 11/11 [==============================] - 34s 3s/step - loss: 0.5380 - categorical_accuracy: 0.7914 - val_loss: 1.7289 - val_categorical_accuracy: 0.6250 - lr: 8.0000e-06
# Epoch 28/30
# 11/11 [==============================] - ETA: 0s - loss: 0.6217 - categorical_accuracy: 0.7861
# Epoch 28: saving model to model_init_2023-01-0910_42_32.286970/model-00028-0.62168-0.78610-0.88709-0.62500.h5
# 11/11 [==============================] - 38s 4s/step - loss: 0.6217 - categorical_accuracy: 0.7861 - val_loss: 0.8871 - val_categorical_accuracy: 0.6250 - lr: 1.6000e-06
# Epoch 29/30
# 11/11 [==============================] - ETA: 0s - loss: 0.5634 - categorical_accuracy: 0.7968
# Epoch 29: saving model to model_init_2023-01-0910_42_32.286970/model-00029-0.56342-0.79679-1.13320-0.62500.h5
# 11/11 [==============================] - 37s 4s/step - loss: 0.5634 - categorical_accuracy: 0.7968 - val_loss: 1.1332 - val_categorical_accuracy: 0.6250 - lr: 1.6000e-06
# Epoch 30/30
# 11/11 [==============================] - ETA: 0s - loss: 0.6119 - categorical_accuracy: 0.7487
# Epoch 30: saving model to model_init_2023-01-0910_42_32.286970/model-00030-0.61185-0.74866-1.18520-0.37500.h5
# 11/11 [==============================] - 38s 4s/step - loss: 0.6119 - categorical_accuracy: 0.7487 - val_loss: 1.1852 - val_categorical_accuracy: 0.3750 - lr: 1.6000e-06

# %%
plotModelHistory(model2_history)
# Out:
# Max. Training Accuracy 0.8021390438079834
# Max. Validaiton Accuracy 0.75

# %% [markdown]
# Reduce parameters, with padding in Conv3D layers and filter of (3,3,3).

# %% [markdown]
# ### Model 3: Frames-30, Epocs-20, Reduced parameters

# %%
n_frames = 30
num_epochs = 20
batch_size = 64

img_tensor = getImgTensor(n_frames)
train_generator = generator(train_path, train_doc, batch_size, img_tensor)
val_generator = generator(val_path, val_doc, batch_size, img_tensor)

if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1
    
inputShape = (len(img_tensor[0]), img_tensor[1], img_tensor[2], img_tensor[3])

model3 = Sequential([
    Conv3D(16, make3dFilter(3), padding='same', activation='relu', input_shape=inputShape),
    MaxPooling3D(make3dFilter(2), padding='same'),
    BatchNormalization(),

    Conv3D(32, make3dFilter(3), padding='same', activation='relu'),
    MaxPooling3D(pool_size=(2), padding='same'),
    BatchNormalization(),

    Conv3D(64, make3dFilter(3), padding='same', activation='relu'),
    MaxPooling3D(pool_size=(2), padding='same'),
    BatchNormalization(),

    Flatten(),
    Dense(128, activation='relu'),
    BatchNormalization(),
    Dropout(0.25),

    Dense(64, activation='relu'),
    BatchNormalization(),
    Dropout(0.25),

    Dense(5, activation='softmax')
], name="conv_3d3")
model3.compile(optimizer=optimizers.Adam(), loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print(model3.summary())

model3_history = model3.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
            callbacks=callbacks_list, validation_data=val_generator, 
            validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Model: "conv_3d3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_9 (Conv3D)           (None, 30, 100, 100, 16)  1312
#
#  max_pooling3d_9 (MaxPooling  (None, 15, 50, 50, 16)   0
#  3D)
#
#  batch_normalization_15 (Bat  (None, 15, 50, 50, 16)   64
#  chNormalization)
#
#  conv3d_10 (Conv3D)          (None, 15, 50, 50, 32)    13856
#
#  max_pooling3d_10 (MaxPoolin  (None, 8, 25, 25, 32)    0
#  g3D)
#
#  batch_normalization_16 (Bat  (None, 8, 25, 25, 32)    128
#  chNormalization)
#
#  conv3d_11 (Conv3D)          (None, 8, 25, 25, 64)     55360
#
#  max_pooling3d_11 (MaxPoolin  (None, 4, 13, 13, 64)    0
#  g3D)
#
#  batch_normalization_17 (Bat  (None, 4, 13, 13, 64)    256
#  chNormalization)
#
#  flatten_3 (Flatten)         (None, 43264)             0
#
#  dense_9 (Dense)             (None, 128)               5537920
#
#  batch_normalization_18 (Bat  (None, 128)              512
#  chNormalization)
#
#  dropout_6 (Dropout)         (None, 128)               0
#
#  dense_10 (Dense)            (None, 64)                8256
#
#  batch_normalization_19 (Bat  (None, 64)               256
#  chNormalization)
#
#  dropout_7 (Dropout)         (None, 64)                0
#
#  dense_11 (Dense)            (None, 5)                 325
#
# =================================================================
# Total params: 5,618,245
# Trainable params: 5,617,637
# Non-trainable params: 608
# _________________________________________________________________
# None
# Source path =  Project_data/train ; batch size = 64
# Epoch 1/20
# 11/11 [==============================] - ETA: 0s - loss: 1.4710 - categorical_accuracy: 0.4374 Source path =  Project_data/val ; batch size = 64
#
# Epoch 1: saving model to model_init_2023-01-0910_42_32.286970/model-00001-1.47097-0.43741-3.50301-0.20000.h5
# 11/11 [==============================] - 153s 15s/step - loss: 1.4710 - categorical_accuracy: 0.4374 - val_loss: 3.5030 - val_categorical_accuracy: 0.2000 - lr: 0.0010
# Epoch 2/20
# 11/11 [==============================] - ETA: 0s - loss: 0.9285 - categorical_accuracy: 0.6601
# Epoch 2: saving model to model_init_2023-01-0910_42_32.286970/model-00002-0.92846-0.66008-2.90144-0.25000.h5
# 11/11 [==============================] - 64s 6s/step - loss: 0.9285 - categorical_accuracy: 0.6601 - val_loss: 2.9014 - val_categorical_accuracy: 0.2500 - lr: 0.0010
# Epoch 3/20
# 11/11 [==============================] - ETA: 0s - loss: 1.0386 - categorical_accuracy: 0.5850
# Epoch 3: saving model to model_init_2023-01-0910_42_32.286970/model-00003-1.03856-0.58498-3.48437-0.21429.h5
# 11/11 [==============================] - 64s 6s/step - loss: 1.0386 - categorical_accuracy: 0.5850 - val_loss: 3.4844 - val_categorical_accuracy: 0.2143 - lr: 0.0010
# Epoch 4/20
# 11/11 [==============================] - ETA: 0s - loss: 0.8692 - categorical_accuracy: 0.6652
# Epoch 4: saving model to model_init_2023-01-0910_42_32.286970/model-00004-0.86921-0.66524-3.20193-0.12500.h5
# 11/11 [==============================] - 54s 5s/step - loss: 0.8692 - categorical_accuracy: 0.6652 - val_loss: 3.2019 - val_categorical_accuracy: 0.1250 - lr: 0.0010
# Epoch 5/20
# 11/11 [==============================] - ETA: 0s - loss: 0.7835 - categorical_accuracy: 0.6986
# Epoch 5: saving model to model_init_2023-01-0910_42_32.286970/model-00005-0.78351-0.69856-1.56433-0.31250.h5
# 11/11 [==============================] - 50s 5s/step - loss: 0.7835 - categorical_accuracy: 0.6986 - val_loss: 1.5643 - val_categorical_accuracy: 0.3125 - lr: 0.0010
# Epoch 6/20
# 11/11 [==============================] - ETA: 0s - loss: 1.2950 - categorical_accuracy: 0.5359
# Epoch 6: saving model to model_init_2023-01-0910_42_32.286970/model-00006-1.29500-0.53589-2.74842-0.12500.h5
# 11/11 [==============================] - 41s 4s/step - loss: 1.2950 - categorical_accuracy: 0.5359 - val_loss: 2.7484 - val_categorical_accuracy: 0.1250 - lr: 0.0010
# Epoch 7/20
# 11/11 [==============================] - ETA: 0s - loss: 1.0169 - categorical_accuracy: 0.6305
# Epoch 7: saving model to model_init_2023-01-0910_42_32.286970/model-00007-1.01695-0.63054-2.34083-0.25000.h5
# 11/11 [==============================] - 40s 4s/step - loss: 1.0169 - categorical_accuracy: 0.6305 - val_loss: 2.3408 - val_categorical_accuracy: 0.2500 - lr: 0.0010
# Epoch 8/20
# 11/11 [==============================] - ETA: 0s - loss: 1.0625 - categorical_accuracy: 0.5775
# Epoch 8: saving model to model_init_2023-01-0910_42_32.286970/model-00008-1.06249-0.57754-5.54332-0.12500.h5
# 11/11 [==============================] - 37s 4s/step - loss: 1.0625 - categorical_accuracy: 0.5775 - val_loss: 5.5433 - val_categorical_accuracy: 0.1250 - lr: 0.0010
# Epoch 9/20
# 11/11 [==============================] - ETA: 0s - loss: 0.8918 - categorical_accuracy: 0.6738
# Epoch 9: saving model to model_init_2023-01-0910_42_32.286970/model-00009-0.89178-0.67380-4.01693-0.25000.h5
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 11/11 [==============================] - 37s 4s/step - loss: 0.8918 - categorical_accuracy: 0.6738 - val_loss: 4.0169 - val_categorical_accuracy: 0.2500 - lr: 0.0010
# Epoch 10/20
# 11/11 [==============================] - ETA: 0s - loss: 0.8616 - categorical_accuracy: 0.6738
# Epoch 10: saving model to model_init_2023-01-0910_42_32.286970/model-00010-0.86161-0.67380-3.20575-0.12500.h5
# 11/11 [==============================] - 38s 4s/step - loss: 0.8616 - categorical_accuracy: 0.6738 - val_loss: 3.2058 - val_categorical_accuracy: 0.1250 - lr: 2.0000e-04
# Epoch 11/20
# 11/11 [==============================] - ETA: 0s - loss: 0.7826 - categorical_accuracy: 0.7273
# Epoch 11: saving model to model_init_2023-01-0910_42_32.286970/model-00011-0.78255-0.72727-4.43254-0.00000.h5
# 11/11 [==============================] - 43s 4s/step - loss: 0.7826 - categorical_accuracy: 0.7273 - val_loss: 4.4325 - val_categorical_accuracy: 0.0000e+00 - lr: 2.0000e-04
# Epoch 12/20
# 11/11 [==============================] - ETA: 0s - loss: 0.6076 - categorical_accuracy: 0.7647
# Epoch 12: saving model to model_init_2023-01-0910_42_32.286970/model-00012-0.60762-0.76471-3.97458-0.00000.h5
# 11/11 [==============================] - 38s 4s/step - loss: 0.6076 - categorical_accuracy: 0.7647 - val_loss: 3.9746 - val_categorical_accuracy: 0.0000e+00 - lr: 2.0000e-04
# Epoch 13/20
# 11/11 [==============================] - ETA: 0s - loss: 0.6686 - categorical_accuracy: 0.6898
# Epoch 13: saving model to model_init_2023-01-0910_42_32.286970/model-00013-0.66855-0.68984-1.30413-0.50000.h5
# 11/11 [==============================] - 36s 4s/step - loss: 0.6686 - categorical_accuracy: 0.6898 - val_loss: 1.3041 - val_categorical_accuracy: 0.5000 - lr: 2.0000e-04
# Epoch 14/20
# 11/11 [==============================] - ETA: 0s - loss: 0.5488 - categorical_accuracy: 0.7807
# Epoch 14: saving model to model_init_2023-01-0910_42_32.286970/model-00014-0.54878-0.78075-2.55724-0.25000.h5
# 11/11 [==============================] - 36s 4s/step - loss: 0.5488 - categorical_accuracy: 0.7807 - val_loss: 2.5572 - val_categorical_accuracy: 0.2500 - lr: 2.0000e-04
# Epoch 15/20
# 11/11 [==============================] - ETA: 0s - loss: 0.6270 - categorical_accuracy: 0.7326
# Epoch 15: saving model to model_init_2023-01-0910_42_32.286970/model-00015-0.62697-0.73262-2.79555-0.25000.h5
# 11/11 [==============================] - 39s 4s/step - loss: 0.6270 - categorical_accuracy: 0.7326 - val_loss: 2.7955 - val_categorical_accuracy: 0.2500 - lr: 2.0000e-04
# Epoch 16/20
# 11/11 [==============================] - ETA: 0s - loss: 0.4532 - categorical_accuracy: 0.8503
# Epoch 16: saving model to model_init_2023-01-0910_42_32.286970/model-00016-0.45322-0.85027-3.03941-0.37500.h5
# 11/11 [==============================] - 36s 4s/step - loss: 0.4532 - categorical_accuracy: 0.8503 - val_loss: 3.0394 - val_categorical_accuracy: 0.3750 - lr: 2.0000e-04
# Epoch 17/20
# 11/11 [==============================] - ETA: 0s - loss: 0.5437 - categorical_accuracy: 0.7754
# Epoch 17: saving model to model_init_2023-01-0910_42_32.286970/model-00017-0.54368-0.77540-2.87169-0.12500.h5
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 11/11 [==============================] - 37s 4s/step - loss: 0.5437 - categorical_accuracy: 0.7754 - val_loss: 2.8717 - val_categorical_accuracy: 0.1250 - lr: 2.0000e-04
# Epoch 18/20
# 11/11 [==============================] - ETA: 0s - loss: 0.5228 - categorical_accuracy: 0.8128
# Epoch 18: saving model to model_init_2023-01-0910_42_32.286970/model-00018-0.52278-0.81283-2.12043-0.25000.h5
# 11/11 [==============================] - 38s 4s/step - loss: 0.5228 - categorical_accuracy: 0.8128 - val_loss: 2.1204 - val_categorical_accuracy: 0.2500 - lr: 4.0000e-05
# Epoch 19/20
# 11/11 [==============================] - ETA: 0s - loss: 0.4983 - categorical_accuracy: 0.8235
# Epoch 19: saving model to model_init_2023-01-0910_42_32.286970/model-00019-0.49827-0.82353-1.71276-0.62500.h5
# 11/11 [==============================] - 38s 4s/step - loss: 0.4983 - categorical_accuracy: 0.8235 - val_loss: 1.7128 - val_categorical_accuracy: 0.6250 - lr: 4.0000e-05
# Epoch 20/20
# 11/11 [==============================] - ETA: 0s - loss: 0.5100 - categorical_accuracy: 0.8182
# Epoch 20: saving model to model_init_2023-01-0910_42_32.286970/model-00020-0.51004-0.81818-2.50881-0.25000.h5
# 11/11 [==============================] - 38s 4s/step - loss: 0.5100 - categorical_accuracy: 0.8182 - val_loss: 2.5088 - val_categorical_accuracy: 0.2500 - lr: 4.0000e-05

# %%
plotModelHistory(model3_history)
# Out:
# Max. Training Accuracy 0.8502673506736755
# Max. Validaiton Accuracy 0.625

# %% [markdown]
# ### Model 4: Frames-20, Same pooling in Conv3D layer

# %%
n_frames = 20
num_epochs = 20
batch_size = 64

img_tensor = getImgTensor(n_frames)
train_generator = generator(train_path, train_doc, batch_size, img_tensor)
val_generator = generator(val_path, val_doc, batch_size, img_tensor)

if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1
    
inputShape = (len(img_tensor[0]), img_tensor[1], img_tensor[2], img_tensor[3])

model4 = Sequential([
    Conv3D(16, make3dFilter(3), padding='same', activation='relu', input_shape=inputShape),
    MaxPooling3D(make3dFilter(2), padding='same'),
    BatchNormalization(),

    Conv3D(32, make3dFilter(3), padding='same', activation='relu'),
    MaxPooling3D(pool_size=(2), padding='same'),
    BatchNormalization(),

    Conv3D(64, make3dFilter(3), padding='same', activation='relu'),
    MaxPooling3D(pool_size=(2), padding='same'),
    BatchNormalization(),

    Conv3D(128, make3dFilter(3), padding='same', activation='relu'),
    MaxPooling3D(pool_size=(2), padding='same'),
    BatchNormalization(),

    Flatten(),
    Dense(128, activation='relu'),
    BatchNormalization(),
    Dropout(0.25),

    Dense(64, activation='relu'),
    BatchNormalization(),
    Dropout(0.25),

    Dense(5, activation='softmax')
], name="conv_3d4")
model4.compile(optimizer=optimizers.Adam(), loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print(model4.summary())

model4_history = model4.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
            callbacks=callbacks_list, validation_data=val_generator, 
            validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Model: "conv_3d4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_12 (Conv3D)          (None, 20, 100, 100, 16)  1312
#
#  max_pooling3d_12 (MaxPoolin  (None, 10, 50, 50, 16)   0
#  g3D)
#
#  batch_normalization_20 (Bat  (None, 10, 50, 50, 16)   64
#  chNormalization)
#
#  conv3d_13 (Conv3D)          (None, 10, 50, 50, 32)    13856
#
#  max_pooling3d_13 (MaxPoolin  (None, 5, 25, 25, 32)    0
#  g3D)
#
#  batch_normalization_21 (Bat  (None, 5, 25, 25, 32)    128
#  chNormalization)
#
#  conv3d_14 (Conv3D)          (None, 5, 25, 25, 64)     55360
#
#  max_pooling3d_14 (MaxPoolin  (None, 3, 13, 13, 64)    0
#  g3D)
#
#  batch_normalization_22 (Bat  (None, 3, 13, 13, 64)    256
#  chNormalization)
#
#  conv3d_15 (Conv3D)          (None, 3, 13, 13, 128)    221312
#
#  max_pooling3d_15 (MaxPoolin  (None, 2, 7, 7, 128)     0
#  g3D)
#
#  batch_normalization_23 (Bat  (None, 2, 7, 7, 128)     512
#  chNormalization)
#
#  flatten_4 (Flatten)         (None, 12544)             0
#
#  dense_12 (Dense)            (None, 128)               1605760
#
#  batch_normalization_24 (Bat  (None, 128)              512
#  chNormalization)
#
#  dropout_8 (Dropout)         (None, 128)               0
#
#  dense_13 (Dense)            (None, 64)                8256
#
#  batch_normalization_25 (Bat  (None, 64)               256
#  chNormalization)
#
#  dropout_9 (Dropout)         (None, 64)                0
#
#  dense_14 (Dense)            (None, 5)                 325
#
# =================================================================
# Total params: 1,907,909
# Trainable params: 1,907,045
# Non-trainable params: 864
# _________________________________________________________________
# None
# Source path =  Project_data/train ; batch size = 64
# Epoch 1/20
#  2/11 [====>.........................] - ETA: 1:20 - loss: 2.0184 - categorical_accuracy: 0.3203

# %%
plotModelHistory(model4_history)

# %% [markdown]
# ### Model 5: Frames:20, Epocs-20, BS-64, reduced kernel to (2,2,2), switching BatchNormalization before MaxPooling.

# %%
n_frames = 20
num_epochs = 20
batch_size = 64

img_tensor = getImgTensor(n_frames)
train_generator = generator(train_path, train_doc, batch_size, img_tensor)
val_generator = generator(val_path, val_doc, batch_size, img_tensor)

if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1
    
inputShape = (len(img_tensor[0]), img_tensor[1], img_tensor[2], img_tensor[3])

model5 = Sequential([
    Conv3D(16, make3dFilter(2), padding='same', activation='relu', input_shape=inputShape),
    BatchNormalization(),
    MaxPooling3D(make3dFilter(2)),

    Conv3D(32, make3dFilter(2), padding='same', activation='relu'),
    BatchNormalization(),
    MaxPooling3D(pool_size=(2)),

    Conv3D(64, make3dFilter(2), padding='same', activation='relu'),
    BatchNormalization(),
    MaxPooling3D(pool_size=(2)),

    Conv3D(128, make3dFilter(2), padding='same', activation='relu'),
    BatchNormalization(),
    MaxPooling3D(pool_size=(2)),

    Flatten(),
    Dense(256, activation='relu'),
    # BatchNormalization(),
    # Dropout(0.3),

    Dense(128, activation='relu'),
    # BatchNormalization(),
    # Dropout(0.2),

    Dense(5, activation='softmax')
], name="conv_3d5")
model5.compile(optimizer=optimizers.Adam(), loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print(model5.summary())

model5_history = model5.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
            callbacks=callbacks_list, validation_data=val_generator, 
            validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)

# %%
plotModelHistory(model5_history)

# %% [markdown]
# ### Model 6: Switching Model architecture to Conv2D+LSTM

# %%
n_frames = 20
num_epochs = 30
batch_size = 64

img_tensor = getImgTensor(n_frames)
train_generator = generator(train_path, train_doc, batch_size, img_tensor)
val_generator = generator(val_path, val_doc, batch_size, img_tensor)

if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1
    
inputShape = (len(img_tensor[0]), img_tensor[1], img_tensor[2], img_tensor[3])

model6 = Sequential([
    TimeDistributed(Conv2D(16, make2dFilter(3), padding='same', activation='relu'), input_shape=inputShape),
    TimeDistributed(BatchNormalization()),
    TimeDistributed(MaxPooling2D(make2dFilter(2))),

    TimeDistributed(Conv2D(32, make2dFilter(3), padding='same', activation='relu')),
    TimeDistributed(BatchNormalization()),
    TimeDistributed(MaxPooling2D(make2dFilter(2))),

    TimeDistributed(Conv2D(64, make2dFilter(3), padding='same', activation='relu')),
    TimeDistributed(BatchNormalization()),
    TimeDistributed(MaxPooling2D(make2dFilter(2))),

    TimeDistributed(Conv2D(128, make2dFilter(3), padding='same', activation='relu')),
    TimeDistributed(BatchNormalization()),
    TimeDistributed(MaxPooling2D(make2dFilter(2))),

    TimeDistributed(Conv2D(256, make2dFilter(3), padding='same', activation='relu')),
    TimeDistributed(BatchNormalization()),
    TimeDistributed(MaxPooling2D(make2dFilter(2))),

    TimeDistributed(Flatten()),
    LSTM(256),
    Dropout(0.2),

    Dense(256, activation='relu'),
    Dropout(0.2),

    Dense(5, activation='softmax')
], name="conv_2d_lstm")
model6.compile(optimizer=optimizers.Adam(), loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print(model6.summary())

model6_history = model6.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
            callbacks=callbacks_list, validation_data=val_generator, 
            validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)

# %%
plotModelHistory(model6_history)

# %% [markdown]
# ### Model 7: Transfer Learning (MobileNet) with LSTM

# %%
from tensorflow.keras.applications import mobilenet

# %%
mobilenet = mobilenet.MobileNet(weights='imagenet', include_top=False)

n_frames = 20
num_epochs = 30
batch_size = 64

img_tensor = getImgTensor(n_frames)
train_generator = generator(train_path, train_doc, batch_size, img_tensor)
val_generator = generator(val_path, val_doc, batch_size, img_tensor)

if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1
    
inputShape = (len(img_tensor[0]), img_tensor[1], img_tensor[2], img_tensor[3])

model7 = Sequential([
    TimeDistributed(mobilenet, input_shape=inputShape)
], name="mobilenet_lstm")

for layer in model7.layers:
    layer.trainable = False

model7.add(TimeDistributed(BatchNormalization()))
model7.add(TimeDistributed(MaxPooling2D(make2dFilter(2))))
model7.add(TimeDistributed(Flatten()))

model7.add(LSTM(256))
model7.add(Dropout(0.2))

model7.add(Dense(256,activation='relu'))
model7.add(Dropout(0.2))

model7.add(Dense(5, activation='softmax'))

model7.compile(optimizer=optimizers.Adam(), loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print(model7.summary())

model7_history = model7.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
            callbacks=callbacks_list, validation_data=val_generator, 
            validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)

# %%
plotModelHistory(model7_history)

# %% [markdown]
# ## We validated the CNN+LSTM model after conducting all the experiments, and it worked great.
#
# #### Below are a few observations:
#
# - Max. Training Accuracy 1.0 and Max. Validaiton Accuracy 0.875
#
# - Learning rate gradually decreacing after 16 Epoch__
#
# - The best weights of CNN-LSTM: <b>model-00018-0.39124-0.87701-0.49787-0.87500.h5</b>. We have considered this weight for model testing.
